# %%
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam

df = pd.read_csv("combined_data.csv")

spatial_features = ['city', 'location_area']
temporal_features = ['year', 'month', 'day', 'hour', 'dayofweek']
environmental_features = ['population', 'crime_rate_per_1000_people']
target_col = 'offense_category_name'

X_spatial = df[spatial_features].copy()
X_temporal = df[temporal_features].copy()
X_env = df[environmental_features].copy()
y = df[target_col].copy()

X_temporal['hour_sin'] = np.sin(2 * np.pi * X_temporal['hour'] / 24)
X_temporal['hour_cos'] = np.cos(2 * np.pi * X_temporal['hour'] / 24)
X_temporal['dayofweek_sin'] = np.sin(2 * np.pi * X_temporal['dayofweek'] / 7)
X_temporal['dayofweek_cos'] = np.cos(2 * np.pi * X_temporal['dayofweek'] / 7)

# Drop the original 'hour' and 'dayofweek' columns
X_temporal = X_temporal.drop(['hour', 'dayofweek'], axis=1)

# Encode spatial categoricals
X_spatial = pd.get_dummies(X_spatial)

# Encode target
le = LabelEncoder()
y_encoded = le.fit_transform(y)

print("Classes:", list(le.classes_))


X_full = np.hstack([X_spatial.values, X_temporal.values, X_env.values])

# Impute missing values before applying SMOTE
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X_full_imputed = imputer.fit_transform(X_full)

# Identify and remove classes with only one sample
unique_classes, class_counts = np.unique(y_encoded, return_counts=True)
classes_to_keep = unique_classes[class_counts > 1]

# Filter data to keep only samples from classes with more than one instance
filtered_indices = np.isin(y_encoded, classes_to_keep)
X_filtered = X_full_imputed[filtered_indices]
y_filtered = y_encoded[filtered_indices]

# Apply SMOTE on the filtered data
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X_filtered, y_filtered)
print("After SMOTE:", np.bincount(y_resampled))

# Recover shapes
spatial_dim = X_spatial.shape[1]
temporal_dim = X_temporal.shape[1]
env_dim = X_env.shape[1]

X_spatial_resampled = X_resampled[:, :spatial_dim]
X_temporal_resampled = X_resampled[:, spatial_dim:spatial_dim+temporal_dim]
X_env_resampled = X_resampled[:, spatial_dim+temporal_dim:]


X_s_train, X_s_test, X_t_train, X_t_test, X_e_train, X_e_test, y_train, y_test = train_test_split(
    X_spatial_resampled, X_temporal_resampled, X_env_resampled, y_resampled, test_size=0.2, random_state=42)

X_s_train, X_s_val, X_t_train, X_t_val, X_e_train, X_e_val, y_train, y_val = train_test_split(
    X_s_train, X_t_train, X_e_train, y_train, test_size=0.1, random_state=42)

# Scale environmental features after splitting
scaler = StandardScaler()
X_e_train = scaler.fit_transform(X_e_train)
X_e_val = scaler.transform(X_e_val)
X_e_test = scaler.transform(X_e_test)


n_classes = len(le.classes_)

# Spatial
input_s = Input(shape=(X_s_train.shape[1],), name='spatial_input')
x1 = Dense(256, activation='relu')(input_s)
x1 = Dropout(0.5)(x1)
x1 = Dense(256, activation='relu')(x1)
x1 = Dropout(0.5)(x1)
x1 = Dense(128, activation='relu')(x1)

# Temporal
input_t = Input(shape=(X_t_train.shape[1],), name='temporal_input')
x2 = Dense(256, activation='relu')(input_t)
x2 = Dropout(0.5)(x2)
x2 = Dense(256, activation='relu')(x2)
x2 = Dropout(0.5)(x2)
x2 = Dense(128, activation='relu')(x2)

# Environmental
input_e = Input(shape=(X_e_train.shape[1],), name='environmental_input')
x3 = Dense(256, activation='relu')(input_e)
x3 = Dropout(0.5)(x3)
x3 = Dense(256, activation='relu')(x3)
x3 = Dropout(0.5)(x3)
x3 = Dense(128, activation='relu')(x3)

# Merge
merged = concatenate([x1, x2, x3])
z = Dense(1024, activation='relu')(merged)
z = Dropout(0.5)(z)
z = Dense(1024, activation='relu')(z)
z = Dropout(0.5)(z)
output = Dense(n_classes, activation='softmax')(z)

# Model
model = Model(inputs=[input_s, input_t, input_e], outputs=output)
model.compile(optimizer=Adam(0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Classes: ['Animal Cruelty', 'Arson', 'Assault Offenses', 'Bribery', 'Burglary/Breaking & Entering', 'Counterfeiting/Forgery', 'Destruction/Damage/Vandalism of Property', 'Drug/Narcotic Offenses', 'Embezzlement', 'Extortion/Blackmail', 'Fraud Offenses', 'Gambling Offenses', 'Homicide Offenses', 'Human Trafficking', 'Kidnapping/Abduction', 'Larceny/Theft Offenses', 'Motor Vehicle Theft', 'Pornography/Obscene Material', 'Prostitution Offenses', 'Robbery', 'Sex Offenses', 'Sex Offenses, Non-forcible', 'Stolen Property Offenses', 'Weapon Law Violations']
# After SMOTE: [121477 121477 121477 121477 121477 121477 121477 121477 121477 121477
#  121477 121477 121477 121477 121477 121477 121477 121477 121477 121477
#  121477 121477 121477 121477]
# After SMOTE: [121477 121477 121477 121477 121477 121477 121477 121477 121477 121477
#  121477 121477 121477 121477 121477 121477 121477 121477 121477 121477
#  121477 121477 121477 121477]
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ spatial_input       │ (None, 141)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ temporal_input      │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ environmental_input │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     36,352 │ spatial_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │      2,048 │ temporal_input[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │        768 │ environmental_in… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     65,792 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │     65,792 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │     65,792 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     32,896 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │     32,896 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 384)       │          0 │ dense_2[0][0],    │
# │ (Concatenate)       │                   │            │ dense_5[0][0],    │
# │                     │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1024)      │    394,240 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1024)      │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1024)      │  1,049,600 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1024)      │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 24)        │     24,600 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,803,672 (6.88 MB)
#  Trainable params: 1,803,672 (6.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define callbacks
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.keras',  # Save in the new Keras format
    save_best_only=True,
    monitor='val_loss',
    verbose=1
)

early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=15,  # Increased patience
    verbose=1,
    restore_best_weights=True
)

# Recompile model with a different optimizer and learning rate
model.compile(optimizer=Adam(learning_rate=0.0005),  # Smaller learning rate
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with the updated callbacks and optimizer
history = model.fit(
    [X_s_train, X_t_train, X_e_train], y_train,
    validation_data=([X_s_val, X_t_val, X_e_val], y_val),
    epochs=50,  # Shortened epochs
    batch_size=256,
    callbacks=[checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0419 - loss: 3.1782
# Epoch 1: val_loss improved from inf to 3.17810, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 222s 26ms/step - accuracy: 0.0419 - loss: 3.1782 - val_accuracy: 0.0423 - val_loss: 3.1781
# Epoch 2/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0414 - loss: 3.1781
# Epoch 2: val_loss improved from 3.17810 to 3.17806, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 214s 26ms/step - accuracy: 0.0414 - loss: 3.1781 - val_accuracy: 0.0428 - val_loss: 3.1781
# Epoch 3/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0517 - loss: 3.1397
# Epoch 3: val_loss improved from 3.17806 to 1.97910, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.0517 - loss: 3.1396 - val_accuracy: 0.3846 - val_loss: 1.9791
# Epoch 4/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3847 - loss: 2.0016
# Epoch 4: val_loss improved from 1.97910 to 1.68960, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.3847 - loss: 2.0016 - val_accuracy: 0.4696 - val_loss: 1.6896
# Epoch 5/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4427 - loss: 1.7944
# Epoch 5: val_loss improved from 1.68960 to 1.60376, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.4427 - loss: 1.7944 - val_accuracy: 0.4889 - val_loss: 1.6038
# Epoch 6/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4613 - loss: 1.7150
# Epoch 6: val_loss improved from 1.60376 to 1.55138, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.4613 - loss: 1.7150 - val_accuracy: 0.5022 - val_loss: 1.5514
# Epoch 7/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4715 - loss: 1.6702
# Epoch 7: val_loss improved from 1.55138 to 1.52245, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.4715 - loss: 1.6702 - val_accuracy: 0.5057 - val_loss: 1.5225
# Epoch 8/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4791 - loss: 1.6383
# Epoch 8: val_loss improved from 1.52245 to 1.49959, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.4791 - loss: 1.6383 - val_accuracy: 0.5125 - val_loss: 1.4996
# Epoch 9/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4848 - loss: 1.6139
# Epoch 9: val_loss improved from 1.49959 to 1.48551, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.4848 - loss: 1.6139 - val_accuracy: 0.5177 - val_loss: 1.4855
# Epoch 10/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4888 - loss: 1.5968
# Epoch 10: val_loss improved from 1.48551 to 1.47207, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.4888 - loss: 1.5968 - val_accuracy: 0.5199 - val_loss: 1.4721
# Epoch 11/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4916 - loss: 1.5851
# Epoch 11: val_loss improved from 1.47207 to 1.46168, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.4916 - loss: 1.5851 - val_accuracy: 0.5231 - val_loss: 1.4617
# Epoch 12/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4942 - loss: 1.5723
# Epoch 12: val_loss improved from 1.46168 to 1.45476, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.4942 - loss: 1.5723 - val_accuracy: 0.5247 - val_loss: 1.4548
# Epoch 13/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4970 - loss: 1.5636
# Epoch 13: val_loss improved from 1.45476 to 1.44668, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.4970 - loss: 1.5636 - val_accuracy: 0.5264 - val_loss: 1.4467
# Epoch 14/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4986 - loss: 1.5551
# Epoch 14: val_loss improved from 1.44668 to 1.44123, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.4986 - loss: 1.5551 - val_accuracy: 0.5283 - val_loss: 1.4412
# Epoch 15/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5009 - loss: 1.5469
# Epoch 15: val_loss improved from 1.44123 to 1.43633, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5009 - loss: 1.5469 - val_accuracy: 0.5282 - val_loss: 1.4363
# Epoch 16/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5026 - loss: 1.5417
# Epoch 16: val_loss improved from 1.43633 to 1.43000, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.5026 - loss: 1.5417 - val_accuracy: 0.5305 - val_loss: 1.4300
# Epoch 17/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5030 - loss: 1.5370
# Epoch 17: val_loss improved from 1.43000 to 1.42600, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5030 - loss: 1.5370 - val_accuracy: 0.5311 - val_loss: 1.4260
# Epoch 18/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5054 - loss: 1.5294
# Epoch 18: val_loss improved from 1.42600 to 1.42339, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5054 - loss: 1.5294 - val_accuracy: 0.5317 - val_loss: 1.4234
# Epoch 19/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5062 - loss: 1.5269
# Epoch 19: val_loss improved from 1.42339 to 1.42129, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 219s 27ms/step - accuracy: 0.5062 - loss: 1.5269 - val_accuracy: 0.5309 - val_loss: 1.4213
# Epoch 20/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5071 - loss: 1.5230
# Epoch 20: val_loss improved from 1.42129 to 1.41563, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5071 - loss: 1.5230 - val_accuracy: 0.5329 - val_loss: 1.4156
# Epoch 21/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5080 - loss: 1.5183
# Epoch 21: val_loss improved from 1.41563 to 1.41324, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5080 - loss: 1.5183 - val_accuracy: 0.5342 - val_loss: 1.4132
# Epoch 22/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5092 - loss: 1.5144
# Epoch 22: val_loss improved from 1.41324 to 1.41163, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 220s 27ms/step - accuracy: 0.5092 - loss: 1.5144 - val_accuracy: 0.5349 - val_loss: 1.4116
# Epoch 23/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5097 - loss: 1.5128
# Epoch 23: val_loss improved from 1.41163 to 1.40768, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5097 - loss: 1.5127 - val_accuracy: 0.5356 - val_loss: 1.4077
# Epoch 24/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5103 - loss: 1.5090
# Epoch 24: val_loss improved from 1.40768 to 1.40638, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5103 - loss: 1.5090 - val_accuracy: 0.5358 - val_loss: 1.4064
# Epoch 25/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5112 - loss: 1.5070
# Epoch 25: val_loss improved from 1.40638 to 1.40279, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.5112 - loss: 1.5070 - val_accuracy: 0.5366 - val_loss: 1.4028
# Epoch 26/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5117 - loss: 1.5039
# Epoch 26: val_loss improved from 1.40279 to 1.40125, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5117 - loss: 1.5039 - val_accuracy: 0.5380 - val_loss: 1.4012
# Epoch 27/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5124 - loss: 1.5018
# Epoch 27: val_loss improved from 1.40125 to 1.40051, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5124 - loss: 1.5018 - val_accuracy: 0.5379 - val_loss: 1.4005
# Epoch 28/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5126 - loss: 1.4990
# Epoch 28: val_loss improved from 1.40051 to 1.39719, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5126 - loss: 1.4990 - val_accuracy: 0.5384 - val_loss: 1.3972
# Epoch 29/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5137 - loss: 1.4959
# Epoch 29: val_loss did not improve from 1.39719
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.5137 - loss: 1.4959 - val_accuracy: 0.5390 - val_loss: 1.3973
# Epoch 30/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5136 - loss: 1.4964
# Epoch 30: val_loss improved from 1.39719 to 1.39470, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5136 - loss: 1.4964 - val_accuracy: 0.5393 - val_loss: 1.3947
# Epoch 31/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5153 - loss: 1.4926
# Epoch 31: val_loss did not improve from 1.39470
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5153 - loss: 1.4926 - val_accuracy: 0.5390 - val_loss: 1.3949
# Epoch 32/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5151 - loss: 1.4911
# Epoch 32: val_loss improved from 1.39470 to 1.38996, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5151 - loss: 1.4911 - val_accuracy: 0.5405 - val_loss: 1.3900
# Epoch 33/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5156 - loss: 1.4890
# Epoch 33: val_loss improved from 1.38996 to 1.38847, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5156 - loss: 1.4890 - val_accuracy: 0.5401 - val_loss: 1.3885
# Epoch 34/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5158 - loss: 1.4886
# Epoch 34: val_loss improved from 1.38847 to 1.38778, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5158 - loss: 1.4886 - val_accuracy: 0.5417 - val_loss: 1.3878
# Epoch 35/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5159 - loss: 1.4869
# Epoch 35: val_loss improved from 1.38778 to 1.38677, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5159 - loss: 1.4869 - val_accuracy: 0.5417 - val_loss: 1.3868
# Epoch 36/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5164 - loss: 1.4852
# Epoch 36: val_loss improved from 1.38677 to 1.38659, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5164 - loss: 1.4852 - val_accuracy: 0.5414 - val_loss: 1.3866
# Epoch 37/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5176 - loss: 1.4830
# Epoch 37: val_loss improved from 1.38659 to 1.38420, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5176 - loss: 1.4830 - val_accuracy: 0.5422 - val_loss: 1.3842
# Epoch 38/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5168 - loss: 1.4834
# Epoch 38: val_loss did not improve from 1.38420
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 214s 26ms/step - accuracy: 0.5168 - loss: 1.4834 - val_accuracy: 0.5416 - val_loss: 1.3852
# Epoch 39/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5177 - loss: 1.4815
# Epoch 39: val_loss did not improve from 1.38420
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 214s 26ms/step - accuracy: 0.5177 - loss: 1.4815 - val_accuracy: 0.5404 - val_loss: 1.3862
# Epoch 40/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5179 - loss: 1.4801
# Epoch 40: val_loss did not improve from 1.38420
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5179 - loss: 1.4801 - val_accuracy: 0.5405 - val_loss: 1.3853
# Epoch 41/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5180 - loss: 1.4797
# Epoch 41: val_loss improved from 1.38420 to 1.38343, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5180 - loss: 1.4797 - val_accuracy: 0.5420 - val_loss: 1.3834
# Epoch 42/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5183 - loss: 1.4795
# Epoch 42: val_loss did not improve from 1.38343
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5183 - loss: 1.4795 - val_accuracy: 0.5420 - val_loss: 1.3843
# Epoch 43/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5180 - loss: 1.4794
# Epoch 43: val_loss improved from 1.38343 to 1.38236, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5180 - loss: 1.4794 - val_accuracy: 0.5422 - val_loss: 1.3824
# Epoch 44/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5184 - loss: 1.4772
# Epoch 44: val_loss did not improve from 1.38236
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5184 - loss: 1.4772 - val_accuracy: 0.5415 - val_loss: 1.3827
# Epoch 45/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5192 - loss: 1.4755
# Epoch 45: val_loss did not improve from 1.38236
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5192 - loss: 1.4755 - val_accuracy: 0.5417 - val_loss: 1.3850
# Epoch 46/50
# 8198/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5196 - loss: 1.4737
# Epoch 46: val_loss improved from 1.38236 to 1.37949, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 216s 26ms/step - accuracy: 0.5195 - loss: 1.4737 - val_accuracy: 0.5436 - val_loss: 1.3795
# Epoch 47/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5188 - loss: 1.4741
# Epoch 47: val_loss improved from 1.37949 to 1.37798, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 218s 27ms/step - accuracy: 0.5188 - loss: 1.4741 - val_accuracy: 0.5428 - val_loss: 1.3780
# Epoch 48/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5197 - loss: 1.4720
# Epoch 48: val_loss did not improve from 1.37798
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 215s 26ms/step - accuracy: 0.5197 - loss: 1.4720 - val_accuracy: 0.5426 - val_loss: 1.3790
# Epoch 49/50
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5196 - loss: 1.4740
# Epoch 49: val_loss improved from 1.37798 to 1.37548, saving model to best_model.keras
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5196 - loss: 1.4740 - val_accuracy: 0.5440 - val_loss: 1.3755
# Epoch 50/50
# 8199/8200 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5205 - loss: 1.4696
# Epoch 50: val_loss did not improve from 1.37548
# 8200/8200 ━━━━━━━━━━━━━━━━━━━━ 217s 26ms/step - accuracy: 0.5205 - loss: 1.4696 - val_accuracy: 0.5430 - val_loss: 1.3768
# Restoring model weights from the end of the best epoch: 49.

# %%
import joblib
joblib.dump(le, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']

# %%
import joblib

# Save the StandardScaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# Persist imputer and spatial dummy columns
import joblib
joblib.dump(imputer, 'imputer.pkl')
ohe_columns = X_spatial.columns.tolist()
joblib.dump(ohe_columns, 'ohe_columns.pkl')

print("Saved imputer.pkl and ohe_columns.pkl")
# Out:
# Saved imputer.pkl and ohe_columns.pkl

# %%
# Save model in compatibility format for TensorFlow 2.13.1
import tensorflow as tf

# Use the legacy format for compatibility
model.save('crime_prediction_model.keras', save_format='keras')
print("Model saved in compatible format as crime_prediction_model.keras")

# Also check current versions
print(f"Current TensorFlow version: {tf.__version__}")
print(f"Current numpy version: {np.__version__}")

import sklearn, joblib
print(f"Current scikit-learn version: {sklearn.__version__}")
print(f"Current joblib version: {joblib.__version__}")
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Model saved in compatible format as crime_prediction_model.keras
# Current TensorFlow version: 2.18.1
# Current numpy version: 2.0.1
# Current scikit-learn version: 1.6.1
# Current joblib version: 1.5.1
